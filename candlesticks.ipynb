# %%
import pandas as pd
import json

# %%
with open('candle.txt', 'r') as f:
    data = f.read()

# %%
% matplotlib inline

# %%
btc_data = pd.read_json(data)

# %%
btc_data
# Out:
#           close                date         high          low         open  \
# 0   6460.261001 2017-11-11 21:45:00  6473.070000  6441.890411  6466.863692
# 1   6400.000000 2017-11-11 22:00:00  6472.157476  6380.000000  6460.261001
# 2   6381.000000 2017-11-11 22:15:00  6404.148552  6380.000000  6404.109201
# 3   6329.757892 2017-11-11 22:30:00  6400.002326  6280.036085  6380.000000
# 4   6294.000000 2017-11-11 22:45:00  6351.000000  6260.000000  6328.000000
# 5   6269.338010 2017-11-11 23:00:00  6305.000000  6200.000000  6283.157467
# 6   6280.000000 2017-11-11 23:15:00  6315.000000  6259.000000  6270.609976
# 7   6289.223772 2017-11-11 23:30:00  6331.275785  6275.000000  6280.000000
# 8   6300.000000 2017-11-11 23:45:00  6324.000000  6283.521823  6295.360000
# 9   6262.000000 2017-11-12 00:00:00  6319.000000  6238.274934  6319.000000
# 10  6275.515494 2017-11-12 00:15:00  6303.000000  6251.000000  6262.000000
# ...

# %%
sec = btc_data['date'][95].timestamp()- btc_data['date'][0].timestamp()

# %%
sec/60/60
# Out:
# 23.75
